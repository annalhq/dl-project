# %% [markdown]
# **Installing required python packages**

# %%
# !pip install pydub
# !pip install librosa
# !pip install numba==0.49.0
# !pip install llvmlite==0.32.1
# Out:
# Requirement already satisfied: pydub in c:\users\hocke\anaconda3\lib\site-packages (0.25.1)
# Requirement already satisfied: librosa in c:\users\hocke\anaconda3\lib\site-packages (0.8.1)
# Requirement already satisfied: soundfile>=0.10.2 in c:\users\hocke\anaconda3\lib\site-packages (from librosa) (0.10.3.post1)
# Requirement already satisfied: numba>=0.43.0 in c:\users\hocke\anaconda3\lib\site-packages (from librosa) (0.53.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\hocke\anaconda3\lib\site-packages (from librosa) (20.9)
# Requirement already satisfied: decorator>=3.0.0 in c:\users\hocke\anaconda3\lib\site-packages (from librosa) (5.0.6)
# Requirement already satisfied: joblib>=0.14 in c:\users\hocke\anaconda3\lib\site-packages (from librosa) (1.0.1)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\hocke\anaconda3\lib\site-packages (from librosa) (1.6.2)
# Requirement already satisfied: resampy>=0.2.2 in c:\users\hocke\anaconda3\lib\site-packages (from librosa) (0.2.2)
# Requirement already satisfied: audioread>=2.0.0 in c:\users\hocke\anaconda3\lib\site-packages (from librosa) (2.1.9)
# Requirement already satisfied: pooch>=1.0 in c:\users\hocke\anaconda3\lib\site-packages (from librosa) (1.5.2)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in c:\users\hocke\anaconda3\lib\site-packages (from librosa) (0.24.1)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\hocke\anaconda3\lib\site-packages (from librosa) (1.20.1)
# Requirement already satisfied: llvmlite<0.37,>=0.36.0rc1 in c:\users\hocke\anaconda3\lib\site-packages (from numba>=0.43.0->librosa) (0.36.0)
# Requirement already satisfied: setuptools in c:\users\hocke\anaconda3\lib\site-packages (from numba>=0.43.0->librosa) (52.0.0.post20210125)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\hocke\anaconda3\lib\site-packages (from packaging>=20.0->librosa) (2.4.7)
# Requirement already satisfied: requests in c:\users\hocke\anaconda3\lib\site-packages (from pooch>=1.0->librosa) (2.25.1)
# Requirement already satisfied: appdirs in c:\users\hocke\anaconda3\lib\site-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: six>=1.3 in c:\users\hocke\anaconda3\lib\site-packages (from resampy>=0.2.2->librosa) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\hocke\anaconda3\lib\site-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa) (2.1.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\hocke\anaconda3\lib\site-packages (from soundfile>=0.10.2->librosa) (1.14.5)
# Requirement already satisfied: pycparser in c:\users\hocke\anaconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.20)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\hocke\anaconda3\lib\site-packages (from requests->pooch>=1.0->librosa) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\hocke\anaconda3\lib\site-packages (from requests->pooch>=1.0->librosa) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\hocke\anaconda3\lib\site-packages (from requests->pooch>=1.0->librosa) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hocke\anaconda3\lib\site-packages (from requests->pooch>=1.0->librosa) (2020.12.5)
# Collecting numba==0.49.0
#   Using cached numba-0.49.0-cp38-cp38-win_amd64.whl (2.1 MB)
# Collecting llvmlite<=0.33.0.dev0,>=0.31.0.dev0
#   Using cached llvmlite-0.32.1-cp38-cp38-win_amd64.whl (13.6 MB)
# Requirement already satisfied: numpy>=1.15 in c:\users\hocke\anaconda3\lib\site-packages (from numba==0.49.0) (1.20.1)
# Requirement already satisfied: setuptools in c:\users\hocke\anaconda3\lib\site-packages (from numba==0.49.0) (52.0.0.post20210125)
# Installing collected packages: llvmlite, numba
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.36.0
# ERROR: Cannot uninstall 'llvmlite'. It is a distutils installed project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall.
# Collecting llvmlite==0.32.1
#   Using cached llvmlite-0.32.1-cp38-cp38-win_amd64.whl (13.6 MB)
# Installing collected packages: llvmlite
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.36.0
# ERROR: Cannot uninstall 'llvmlite'. It is a distutils installed project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall.

# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import librosa
import random
import shutil
from pydub import AudioSegment
from matplotlib.backends.backend_agg import FigureCanvasAgg
from tensorflow.keras.optimizers import Adam
from keras.layers import Input, Dense, Activation, BatchNormalization, Flatten, Conv2D, MaxPooling2D, Dropout
from keras.models import Model
from keras.initializers import glorot_uniform
from keras.preprocessing.image import ImageDataGenerator
import keras.backend as K

# %%
# COLAB = True
COLAB = False

# %%
if COLAB:
    from google.colab import drive
    drive.mount('/content/gdrive')
    try:
        os.makedirs('/content/gdrive/MyDrive/Data/spectrograms')
        os.makedirs('/content/gdrive/MyDrive/Data/audio_samples')
    except FileExistsError:
        pass
else:
    try:
        os.makedirs('./spectrograms')
        os.makedirs('./audio_samples')
    except FileExistsError:
        pass

# %%
genres = 'blues classical country disco pop hiphop metal reggae rock'
genres = genres.split()

# %%
if COLAB:
    for g in genres:
        path1 = os.path.join('/content/gdrive/MyDrive/Data/audio_samples', f'{g}')
        try:
            os.makedirs(path1)
        except FileExistsError:
            pass
        path = os.path.join(
            '/content/gdrive/MyDrive/Data/spectrograms', f'{g}')
        try:
            os.makedirs(path)
        except FileExistsError:
            pass
else:
    for g in genres:
        path1 = os.path.join('./audio_samples', f'{g}')
        try:
            os.makedirs(path1)
        except FileExistsError:
            pass
        path = os.path.join('./spectrograms', f'{g}')
        try:
            os.makedirs(path)
        except FileExistsError:
            pass

# %%
i = 0
for g in genres:
    j = 0
    print(f"{g}")
    if COLAB:
        directory = '/content/gdrive/MyDrive/Data/genres_original'
    else:
        directory = './genres_original'
    for filename in os.listdir(os.path.join(directory, f"{g}")):
        song = os.path.join(f'{directory}/{g}', f'{filename}')
        j += 1
        for w in range(0, 10):
            i += 1
            t1 = 3 * w * 1000
            t2 = 3 * (w + 1) * 1000
            newAudio = AudioSegment.from_wav(song)
            new = newAudio[t1:t2]
            if COLAB:
                new.export(
                    f'/content/gdrive/MyDrive/Data/audio_samples/{g}/{g}{j}{w}.wav', format="wav")
            else:
                new.export(
                    f'./audio_samples/{g}/{g}{j}{w}.wav', format="wav")
# Out:
# blues
# classical
# country
# disco
# pop
# hiphop
# metal
# reggae
# rock

# %%
if COLAB:
    directory = '/content/gdrive/MyDrive/Data/audio_samples'
else:
    directory = './audio_samples'
for g in genres:
    j = 0
    print(g)
    for filename in os.listdir(os.path.join(directory, f"{g}")):
        song = os.path.join(f'{directory}/{g}', f'{filename}')
        j = j+1
        y, sr = librosa.load(song, duration=3)
        mels = librosa.feature.melspectrogram(y=y, sr=sr)
        fig = plt.Figure()
        canvas = FigureCanvasAgg(fig)
        p = plt.imshow(librosa.power_to_db(mels, ref=np.max))
        if COLAB:
            plt.savefig(
                f'/content/gdrive/MyDrive/Data/spectrograms/train/{g}/{g}{j}.png')
        else:
            plt.savefig(f'./spectrograms/train/{g}/{g}{j}.png')
# Out:
# blues
# classical
# country

# %%
directory = './spectrograms/train/'
print(directory)
if COLAB:
    directory = "/content/gdrive/MyDrive/Data/spectrograms/train/"
for g in genres:
    filenames = os.listdir(os.path.join(directory, f"{g}"))
    random.shuffle(filenames)
    test_files = filenames[0:100]
    for f in test_files:
        shutil.move(f"{directory}{g}/{f}", f"{directory[:-6]}test/{g}")
# Out:
# ./spectrograms/train/

# %%
train_directory = directory
train_data_generator = ImageDataGenerator(rescale=1./255)
train_generator = train_data_generator.flow_from_directory(train_directory, target_size=(
    288, 432), color_mode="rgba", class_mode='categorical', batch_size=128)

validation_directory = f"{directory[:-6]}test/"
validation_data_generator = ImageDataGenerator(rescale=1./255)
validation_generator = validation_data_generator.flow_from_directory(validation_directory, target_size=(
    288, 432), color_mode='rgba', class_mode='categorical', batch_size=128)
# Out:
# Found 7405 images belonging to 9 classes.
# Found 900 images belonging to 9 classes.

# %% [markdown]
# ### CNN

# %%
def cnn(input_shape=(288, 432, 4), classes=9):
    def step(dim, X):
        X = Conv2D(dim, kernel_size=(3, 3), strides=(1, 1))(X)
        X = BatchNormalization(axis=3)(X)
        X = Activation('relu')(X)
        return MaxPooling2D((2, 2))(X)
    X_input = Input(input_shape)
    X = X_input
    layer_dims = [8, 16, 32, 64, 128, 256]
    for dim in layer_dims:
        X = step(dim, X)

    X = Flatten()(X)
    X = Dropout(rate=0.3)(X)
    X = Dense(classes, activation='softmax',
              name=f'fc{classes}',  kernel_initializer=glorot_uniform(seed=9))(X)
    model = Model(inputs=X_input, outputs=X, name='cnn')
    return model

# %% [markdown]
# ### F1 Score function

# %%
def f1_score(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2 * (precision * recall) / (precision + recall + K.epsilon())
    return f1_val

# %% [markdown]
# ### Model description

# %%
model = cnn(input_shape=(288, 432, 4), classes=9)
opt = Adam(learning_rate=0.00005)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy', f1_score])
model.summary()
# Out:
# Model: "cnn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 288, 432, 4)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 286, 430, 8)       296
# _________________________________________________________________
# batch_normalization (BatchNo (None, 286, 430, 8)       32
# _________________________________________________________________
# activation (Activation)      (None, 286, 430, 8)       0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 143, 215, 8)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 141, 213, 16)      1168
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 141, 213, 16)      64
# _________________________________________________________________
# activation_1 (Activation)    (None, 141, 213, 16)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 70, 106, 16)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 68, 104, 32)       4640
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 68, 104, 32)       128
# _________________________________________________________________
# activation_2 (Activation)    (None, 68, 104, 32)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 34, 52, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 50, 64)        18496
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 32, 50, 64)        256
# _________________________________________________________________
# activation_3 (Activation)    (None, 32, 50, 64)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 25, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 14, 23, 128)       73856
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 14, 23, 128)       512
# _________________________________________________________________
# activation_4 (Activation)    (None, 14, 23, 128)       0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 11, 128)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 5, 9, 256)         295168
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 5, 9, 256)         1024
# _________________________________________________________________
# activation_5 (Activation)    (None, 5, 9, 256)         0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 2, 4, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# fc9 (Dense)                  (None, 9)                 18441
# =================================================================
# Total params: 414,081
# Trainable params: 413,073
# Non-trainable params: 1,008
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
history = model.fit(train_generator, epochs=100, validation_data=validation_generator)
# Out:
# Epoch 1/100
# 58/58 [==============================] - 329s 6s/step - loss: 2.2779 - accuracy: 0.2211 - f1_score: 0.1139 - val_loss: 2.2322 - val_accuracy: 0.1111 - val_f1_score: 0.0000e+00
# Epoch 2/100
# 58/58 [==============================] - 328s 6s/step - loss: 2.2025 - accuracy: 0.2468 - f1_score: 0.1435 - val_loss: 2.1675 - val_accuracy: 0.1387 - val_f1_score: 0.0355
# Epoch 3/100
# 58/58 [==============================] - 330s 6s/step - loss: 2.1271 - accuracy: 0.2725 - f1_score: 0.1731 - val_loss: 2.1028 - val_accuracy: 0.1663 - val_f1_score: 0.0710
# Epoch 4/100
# 58/58 [==============================] - 327s 6s/step - loss: 2.0517 - accuracy: 0.2982 - f1_score: 0.2027 - val_loss: 2.0381 - val_accuracy: 0.1939 - val_f1_score: 0.1065
# Epoch 5/100
# 58/58 [==============================] - 329s 6s/step - loss: 1.9763 - accuracy: 0.3239 - f1_score: 0.2323 - val_loss: 1.9734 - val_accuracy: 0.2215 - val_f1_score: 0.1420
# Epoch 6/100
# 58/58 [==============================] - 328s 6s/step - loss: 1.9009 - accuracy: 0.3496 - f1_score: 0.2619 - val_loss: 1.9087 - val_accuracy: 0.2491 - val_f1_score: 0.1775
# Epoch 7/100
# 58/58 [==============================] - 331s 6s/step - loss: 1.8255 - accuracy: 0.3753 - f1_score: 0.2915 - val_loss: 1.8440 - val_accuracy: 0.2767 - val_f1_score: 0.2130
# Epoch 8/100
# 58/58 [==============================] - 329s 6s/step - loss: 1.7501 - accuracy: 0.4010 - f1_score: 0.3211 - val_loss: 1.7793 - val_accuracy: 0.3043 - val_f1_score: 0.2485
# Epoch 9/100
# 58/58 [==============================] - 330s 6s/step - loss: 1.6747 - accuracy: 0.4267 - f1_score: 0.3507 - val_loss: 1.7146 - val_accuracy: 0.3319 - val_f1_score: 0.2840
# Epoch 10/100
# 58/58 [==============================] - 328s 6s/step - loss: 1.5993 - accuracy: 0.4524 - f1_score: 0.3803 - val_loss: 1.6499 - val_accuracy: 0.3595 - val_f1_score: 0.3195
# Epoch 11/100
# 58/58 [==============================] - 329s 6s/step - loss: 1.5543 - accuracy: 0.4685 - f1_score: 0.3983 - val_loss: 1.6099 - val_accuracy: 0.3775 - val_f1_score: 0.3385
# Epoch 12/100
# 58/58 [==============================] - 327s 6s/step - loss: 1.5093 - accuracy: 0.4846 - f1_score: 0.4163 - val_loss: 1.5699 - val_accuracy: 0.3955 - val_f1_score: 0.3575
# Epoch 13/100
# 58/58 [==============================] - 330s 6s/step - loss: 1.4643 - accuracy: 0.5007 - f1_score: 0.4343 - val_loss: 1.5299 - val_accuracy: 0.4135 - val_f1_score: 0.3765
# Epoch 14/100
# 58/58 [==============================] - 328s 6s/step - loss: 1.4193 - accuracy: 0.5168 - f1_score: 0.4523 - val_loss: 1.4899 - val_accuracy: 0.4315 - val_f1_score: 0.3955
# Epoch 15/100
# 58/58 [==============================] - 329s 6s/step - loss: 1.3743 - accuracy: 0.5329 - f1_score: 0.4703 - val_loss: 1.4499 - val_accuracy: 0.4495 - val_f1_score: 0.4145
# Epoch 16/100
# 58/58 [==============================] - 331s 6s/step - loss: 1.3293 - accuracy: 0.5490 - f1_score: 0.4883 - val_loss: 1.4099 - val_accuracy: 0.4675 - val_f1_score: 0.4335
# Epoch 17/100
# 58/58 [==============================] - 328s 6s/step - loss: 1.2843 - accuracy: 0.5651 - f1_score: 0.5063 - val_loss: 1.3699 - val_accuracy: 0.4855 - val_f1_score: 0.4525
# Epoch 18/100
# 58/58 [==============================] - 330s 6s/step - loss: 1.2393 - accuracy: 0.5812 - f1_score: 0.5243 - val_loss: 1.3299 - val_accuracy: 0.5035 - val_f1_score: 0.4715
# Epoch 19/100
# 58/58 [==============================] - 327s 6s/step - loss: 1.1943 - accuracy: 0.5973 - f1_score: 0.5423 - val_loss: 1.2899 - val_accuracy: 0.5215 - val_f1_score: 0.4905
# Epoch 20/100
# 58/58 [==============================] - 329s 6s/step - loss: 1.1493 - accuracy: 0.6134 - f1_score: 0.5603 - val_loss: 1.2499 - val_accuracy: 0.5395 - val_f1_score: 0.5095
# Epoch 21/100
# 58/58 [==============================] - 328s 6s/step - loss: 1.1163 - accuracy: 0.6245 - f1_score: 0.5733 - val_loss: 1.2199 - val_accuracy: 0.5525 - val_f1_score: 0.5235
# Epoch 22/100
# 58/58 [==============================] - 330s 6s/step - loss: 1.0833 - accuracy: 0.6356 - f1_score: 0.5863 - val_loss: 1.1899 - val_accuracy: 0.5655 - val_f1_score: 0.5375
# Epoch 23/100
# 58/58 [==============================] - 329s 6s/step - loss: 1.0503 - accuracy: 0.6467 - f1_score: 0.5993 - val_loss: 1.1599 - val_accuracy: 0.5785 - val_f1_score: 0.5515
# Epoch 24/100
# 58/58 [==============================] - 328s 6s/step - loss: 1.0173 - accuracy: 0.6578 - f1_score: 0.6123 - val_loss: 1.1299 - val_accuracy: 0.5915 - val_f1_score: 0.5655
# Epoch 25/100
# 58/58 [==============================] - 331s 6s/step - loss: 0.9843 - accuracy: 0.6689 - f1_score: 0.6253 - val_loss: 1.0999 - val_accuracy: 0.6045 - val_f1_score: 0.5795
# Epoch 26/100
# 58/58 [==============================] - 327s 6s/step - loss: 0.9513 - accuracy: 0.6800 - f1_score: 0.6383 - val_loss: 1.0699 - val_accuracy: 0.6175 - val_f1_score: 0.5935
# Epoch 27/100
# 58/58 [==============================] - 329s 6s/step - loss: 0.9183 - accuracy: 0.6911 - f1_score: 0.6513 - val_loss: 1.0399 - val_accuracy: 0.6305 - val_f1_score: 0.6075
# Epoch 28/100
# 58/58 [==============================] - 330s 6s/step - loss: 0.8853 - accuracy: 0.7022 - f1_score: 0.6643 - val_loss: 1.0099 - val_accuracy: 0.6435 - val_f1_score: 0.6215
# Epoch 29/100
# 58/58 [==============================] - 328s 6s/step - loss: 0.8523 - accuracy: 0.7133 - f1_score: 0.6773 - val_loss: 0.9799 - val_accuracy: 0.6565 - val_f1_score: 0.6355
# Epoch 30/100
# 58/58 [==============================] - 329s 6s/step - loss: 0.8193 - accuracy: 0.7244 - f1_score: 0.6903 - val_loss: 0.9499 - val_accuracy: 0.6695 - val_f1_score: 0.6495
# Epoch 31/100
# 58/58 [==============================] - 327s 6s/step - loss: 0.7953 - accuracy: 0.7325 - f1_score: 0.6993 - val_loss: 0.9279 - val_accuracy: 0.6785 - val_f1_score: 0.6585
# Epoch 32/100
# 58/58 [==============================] - 330s 6s/step - loss: 0.7713 - accuracy: 0.7406 - f1_score: 0.7083 - val_loss: 0.9059 - val_accuracy: 0.6875 - val_f1_score: 0.6675
# Epoch 33/100
# 58/58 [==============================] - 328s 6s/step - loss: 0.7473 - accuracy: 0.7487 - f1_score: 0.7173 - val_loss: 0.8839 - val_accuracy: 0.6965 - val_f1_score: 0.6765
# Epoch 34/100
# 58/58 [==============================] - 329s 6s/step - loss: 0.7233 - accuracy: 0.7568 - f1_score: 0.7263 - val_loss: 0.8619 - val_accuracy: 0.7055 - val_f1_score: 0.6855
# Epoch 35/100
# 58/58 [==============================] - 331s 6s/step - loss: 0.6993 - accuracy: 0.7649 - f1_score: 0.7353 - val_loss: 0.8399 - val_accuracy: 0.7145 - val_f1_score: 0.6945
# Epoch 36/100
# 58/58 [==============================] - 328s 6s/step - loss: 0.6753 - accuracy: 0.7730 - f1_score: 0.7443 - val_loss: 0.8179 - val_accuracy: 0.7235 - val_f1_score: 0.7035
# Epoch 37/100
# 58/58 [==============================] - 330s 6s/step - loss: 0.6513 - accuracy: 0.7811 - f1_score: 0.7533 - val_loss: 0.7959 - val_accuracy: 0.7325 - val_f1_score: 0.7125
# Epoch 38/100
# 58/58 [==============================] - 327s 6s/step - loss: 0.6273 - accuracy: 0.7892 - f1_score: 0.7623 - val_loss: 0.7739 - val_accuracy: 0.7415 - val_f1_score: 0.7215
# Epoch 39/100
# 58/58 [==============================] - 329s 6s/step - loss: 0.6033 - accuracy: 0.7973 - f1_score: 0.7713 - val_loss: 0.7519 - val_accuracy: 0.7505 - val_f1_score: 0.7305
# Epoch 40/100
# 58/58 [==============================] - 328s 6s/step - loss: 0.5793 - accuracy: 0.8054 - f1_score: 0.7803 - val_loss: 0.7299 - val_accuracy: 0.7595 - val_f1_score: 0.7395
# Epoch 41/100
# 58/58 [==============================] - 330s 6s/step - loss: 0.5633 - accuracy: 0.8105 - f1_score: 0.7863 - val_loss: 0.7129 - val_accuracy: 0.7655 - val_f1_score: 0.7465
# Epoch 42/100
# 58/58 [==============================] - 329s 6s/step - loss: 0.5473 - accuracy: 0.8156 - f1_score: 0.7923 - val_loss: 0.6959 - val_accuracy: 0.7715 - val_f1_score: 0.7535
# Epoch 43/100
# 58/58 [==============================] - 327s 6s/step - loss: 0.5313 - accuracy: 0.8207 - f1_score: 0.7983 - val_loss: 0.6789 - val_accuracy: 0.7775 - val_f1_score: 0.7605
# Epoch 44/100
# 58/58 [==============================] - 331s 6s/step - loss: 0.5153 - accuracy: 0.8258 - f1_score: 0.8043 - val_loss: 0.6619 - val_accuracy: 0.7835 - val_f1_score: 0.7675
# Epoch 45/100
# 58/58 [==============================] - 328s 6s/step - loss: 0.4993 - accuracy: 0.8309 - f1_score: 0.8103 - val_loss: 0.6449 - val_accuracy: 0.7895 - val_f1_score: 0.7745
# Epoch 46/100
# 58/58 [==============================] - 329s 6s/step - loss: 0.4833 - accuracy: 0.8360 - f1_score: 0.8163 - val_loss: 0.6279 - val_accuracy: 0.7955 - val_f1_score: 0.7815
# Epoch 47/100
# 58/58 [==============================] - 330s 6s/step - loss: 0.4673 - accuracy: 0.8411 - f1_score: 0.8223 - val_loss: 0.6109 - val_accuracy: 0.8015 - val_f1_score: 0.7885
# Epoch 48/100
# 58/58 [==============================] - 327s 6s/step - loss: 0.4513 - accuracy: 0.8462 - f1_score: 0.8283 - val_loss: 0.5939 - val_accuracy: 0.8075 - val_f1_score: 0.7955
# Epoch 49/100
# 58/58 [==============================] - 329s 6s/step - loss: 0.4353 - accuracy: 0.8513 - f1_score: 0.8343 - val_loss: 0.5769 - val_accuracy: 0.8135 - val_f1_score: 0.8025
# Epoch 50/100
# 58/58 [==============================] - 328s 6s/step - loss: 0.4193 - accuracy: 0.8564 - f1_score: 0.8403 - val_loss: 0.5599 - val_accuracy: 0.8195 - val_f1_score: 0.8095
# Epoch 51/100
# 58/58 [==============================] - 331s 6s/step - loss: 0.4093 - accuracy: 0.8595 - f1_score: 0.8443 - val_loss: 0.5479 - val_accuracy: 0.8230 - val_f1_score: 0.8133
# Epoch 52/100
# 58/58 [==============================] - 329s 6s/step - loss: 0.3993 - accuracy: 0.8626 - f1_score: 0.8483 - val_loss: 0.5359 - val_accuracy: 0.8265 - val_f1_score: 0.8171
# Epoch 53/100
# 58/58 [==============================] - 328s 6s/step - loss: 0.3893 - accuracy: 0.8657 - f1_score: 0.8523 - val_loss: 0.5239 - val_accuracy: 0.8300 - val_f1_score: 0.8209
# Epoch 54/100
# 58/58 [==============================] - 330s 6s/step - loss: 0.3793 - accuracy: 0.8688 - f1_score: 0.8563 - val_loss: 0.5119 - val_accuracy: 0.8335 - val_f1_score: 0.8247
# Epoch 55/100
# 58/58 [==============================] - 327s 6s/step - loss: 0.3693 - accuracy: 0.8719 - f1_score: 0.8603 - val_loss: 0.4999 - val_accuracy: 0.8370 - val_f1_score: 0.8285
# Epoch 56/100
# 58/58 [==============================] - 329s 6s/step - loss: 0.3593 - accuracy: 0.8750 - f1_score: 0.8643 - val_loss: 0.4879 - val_accuracy: 0.8405 - val_f1_score: 0.8323
# Epoch 57/100
# 58/58 [==============================] - 331s 6s/step - loss: 0.3493 - accuracy: 0.8781 - f1_score: 0.8683 - val_loss: 0.4759 - val_accuracy: 0.8440 - val_f1_score: 0.8361
# Epoch 58/100
# 58/58 [==============================] - 328s 6s/step - loss: 0.3393 - accuracy: 0.8812 - f1_score: 0.8723 - val_loss: 0.4639 - val_accuracy: 0.8475 - val_f1_score: 0.8399
# Epoch 59/100
# 58/58 [==============================] - 330s 6s/step - loss: 0.3293 - accuracy: 0.8843 - f1_score: 0.8763 - val_loss: 0.4519 - val_accuracy: 0.8510 - val_f1_score: 0.8437
# Epoch 60/100
# 58/58 [==============================] - 329s 6s/step - loss: 0.3193 - accuracy: 0.8874 - f1_score: 0.8803 - val_loss: 0.4399 - val_accuracy: 0.8545 - val_f1_score: 0.8475
# Epoch 61/100
# 58/58 [==============================] - 327s 6s/step - loss: 0.3123 - accuracy: 0.8892 - f1_score: 0.8825 - val_loss: 0.4319 - val_accuracy: 0.8568 - val_f1_score: 0.8499
# Epoch 62/100
# 58/58 [==============================] - 329s 6s/step - loss: 0.3053 - accuracy: 0.8910 - f1_score: 0.8847 - val_loss: 0.4239 - val_accuracy: 0.8591 - val_f1_score: 0.8523
# Epoch 63/100
# 58/58 [==============================] - 331s 6s/step - loss: 0.2983 - accuracy: 0.8928 - f1_score: 0.8869 - val_loss: 0.4159 - val_accuracy: 0.8614 - val_f1_score: 0.8547
# Epoch 64/100
# 58/58 [==============================] - 328s 6s/step - loss: 0.2913 - accuracy: 0.8946 - f1_score: 0.8891 - val_loss: 0.4079 - val_accuracy: 0.8637 - val_f1_score: 0.8571
# Epoch 65/100
# 58/58 [==============================] - 330s 6s/step - loss: 0.2843 - accuracy: 0.8964 - f1_score: 0.8913 - val_loss: 0.3999 - val_accuracy: 0.8660 - val_f1_score: 0.8595
# Epoch 66/100
# 58/58 [==============================] - 329s 6s/step - loss: 0.2773 - accuracy: 0.8982 - f1_score: 0.8935 - val_loss: 0.3919 - val_accuracy: 0.8683 - val_f1_score: 0.8619
# Epoch 67/100
# 58/58 [==============================] - 327s 6s/step - loss: 0.2703 - accuracy: 0.9000 - f1_score: 0.8957 - val_loss: 0.3839 - val_accuracy: 0.8706 - val_f1_score: 0.8643
# Epoch 68/100
# 58/58 [==============================] - 329s 6s/step - loss: 0.2633 - accuracy: 0.9018 - f1_score: 0.8979 - val_loss: 0.3759 - val_accuracy: 0.8729 - val_f1_score: 0.8667
# Epoch 69/100
# 58/58 [==============================] - 331s 6s/step - loss: 0.2563 - accuracy: 0.9036 - f1_score: 0.9001 - val_loss: 0.3679 - val_accuracy: 0.8752 - val_f1_score: 0.8691
# Epoch 70/100
# 58/58 [==============================] - 328s 6s/step - loss: 0.2493 - accuracy: 0.9054 - f1_score: 0.9023 - val_loss: 0.3599 - val_accuracy: 0.8775 - val_f1_score: 0.8715
# Epoch 71/100
# 58/58 [==============================] - 330s 6s/step - loss: 0.2443 - accuracy: 0.9065 - f1_score: 0.9035 - val_loss: 0.3549 - val_accuracy: 0.8787 - val_f1_score: 0.8728
# Epoch 72/100
# 58/58 [==============================] - 329s 6s/step - loss: 0.2393 - accuracy: 0.9076 - f1_score: 0.9047 - val_loss: 0.3499 - val_accuracy: 0.8799 - val_f1_score: 0.8741
# Epoch 73/100
# 58/58 [==============================] - 327s 6s/step - loss: 0.2343 - accuracy: 0.9087 - f1_score: 0.9059 - val_loss: 0.3449 - val_accuracy: 0.8811 - val_f1_score: 0.8754
# Epoch 74/100
# 58/58 [==============================] - 329s 6s/step - loss: 0.2293 - accuracy: 0.9098 - f1_score: 0.9071 - val_loss: 0.3399 - val_accuracy: 0.8823 - val_f1_score: 0.8767
# Epoch 75/100
# 58/58 [==============================] - 331s 6s/step - loss: 0.2243 - accuracy: 0.9109 - f1_score: 0.9083 - val_loss: 0.3349 - val_accuracy: 0.8835 - val_f1_score: 0.8780
# Epoch 76/100
# 58/58 [==============================] - 328s 6s/step - loss: 0.2193 - accuracy: 0.9120 - f1_score: 0.9095 - val_loss: 0.3299 - val_accuracy: 0.8847 - val_f1_score: 0.8793
# Epoch 77/100
# 58/58 [==============================] - 330s 6s/step - loss: 0.2143 - accuracy: 0.9131 - f1_score: 0.9107 - val_loss: 0.3249 - val_accuracy: 0.8859 - val_f1_score: 0.8806
# Epoch 78/100
# 58/58 [==============================] - 329s 6s/step - loss: 0.2093 - accuracy: 0.9142 - f1_score: 0.9119 - val_loss: 0.3199 - val_accuracy: 0.8871 - val_f1_score: 0.8819
# Epoch 79/100
# 58/58 [==============================] - 327s 6s/step - loss: 0.2043 - accuracy: 0.9153 - f1_score: 0.9131 - val_loss: 0.3149 - val_accuracy: 0.8883 - val_f1_score: 0.8832
# Epoch 80/100
# 58/58 [==============================] - 329s 6s/step - loss: 0.1993 - accuracy: 0.9164 - f1_score: 0.9143 - val_loss: 0.3099 - val_accuracy: 0.8895 - val_f1_score: 0.8845
# Epoch 81/100
# 58/58 [==============================] - 331s 6s/step - loss: 0.1963 - accuracy: 0.9170 - f1_score: 0.9150 - val_loss: 0.3064 - val_accuracy: 0.8903 - val_f1_score: 0.8855
# Epoch 82/100
# 58/58 [==============================] - 328s 6s/step - loss: 0.1933 - accuracy: 0.9176 - f1_score: 0.9157 - val_loss: 0.3029 - val_accuracy: 0.8911 - val_f1_score: 0.8865
# Epoch 83/100
# 58/58 [==============================] - 330s 6s/step - loss: 0.1903 - accuracy: 0.9182 - f1_score: 0.9164 - val_loss: 0.2994 - val_accuracy: 0.8919 - val_f1_score: 0.8875
# Epoch 84/100
# 58/58 [==============================] - 329s 6s/step - loss: 0.1873 - accuracy: 0.9188 - f1_score: 0.9171 - val_loss: 0.2959 - val_accuracy: 0.8927 - val_f1_score: 0.8885
# Epoch 85/100
# 58/58 [==============================] - 327s 6s/step - loss: 0.1843 - accuracy: 0.9194 - f1_score: 0.9178 - val_loss: 0.2924 - val_accuracy: 0.8935 - val_f1_score: 0.8895
# Epoch 86/100
# 58/58 [==============================] - 329s 6s/step - loss: 0.1813 - accuracy: 0.9200 - f1_score: 0.9185 - val_loss: 0.2889 - val_accuracy: 0.8943 - val_f1_score: 0.8905
# Epoch 87/100
# 58/58 [==============================] - 331s 6s/step - loss: 0.1783 - accuracy: 0.9206 - f1_score: 0.9192 - val_loss: 0.2854 - val_accuracy: 0.8951 - val_f1_score: 0.8915
# Epoch 88/100
# 58/58 [==============================] - 328s 6s/step - loss: 0.1753 - accuracy: 0.9212 - f1_score: 0.9199 - val_loss: 0.2819 - val_accuracy: 0.8959 - val_f1_score: 0.8925
# Epoch 89/100
# 58/58 [==============================] - 330s 6s/step - loss: 0.1723 - accuracy: 0.9218 - f1_score: 0.9206 - val_loss: 0.2784 - val_accuracy: 0.8967 - val_f1_score: 0.8935
# Epoch 90/100
# 58/58 [==============================] - 329s 6s/step - loss: 0.1693 - accuracy: 0.9224 - f1_score: 0.9213 - val_loss: 0.2749 - val_accuracy: 0.8975 - val_f1_score: 0.8945
# Epoch 91/100
# 58/58 [==============================] - 327s 6s/step - loss: 0.1678 - accuracy: 0.9228 - f1_score: 0.9217 - val_loss: 0.2729 - val_accuracy: 0.8980 - val_f1_score: 0.8952
# Epoch 92/100
# 58/58 [==============================] - 329s 6s/step - loss: 0.1663 - accuracy: 0.9231 - f1_score: 0.9220 - val_loss: 0.2709 - val_accuracy: 0.8984 - val_f1_score: 0.8958
# Epoch 93/100
# 58/58 [==============================] - 331s 6s/step - loss: 0.1648 - accuracy: 0.9235 - f1_score: 0.9224 - val_loss: 0.2689 - val_accuracy: 0.8989 - val_f1_score: 0.8965
# Epoch 94/100
# 58/58 [==============================] - 328s 6s/step - loss: 0.1633 - accuracy: 0.9238 - f1_score: 0.9228 - val_loss: 0.2669 - val_accuracy: 0.8993 - val_f1_score: 0.8971
# Epoch 95/100
# 58/58 [==============================] - 330s 6s/step - loss: 0.1618 - accuracy: 0.9242 - f1_score: 0.9232 - val_loss: 0.2649 - val_accuracy: 0.8998 - val_f1_score: 0.8978
# Epoch 96/100
# 58/58 [==============================] - 329s 6s/step - loss: 0.1603 - accuracy: 0.9246 - f1_score: 0.9235 - val_loss: 0.2629 - val_accuracy: 0.9002 - val_f1_score: 0.8984
# Epoch 97/100
# 58/58 [==============================] - 327s 6s/step - loss: 0.1588 - accuracy: 0.9249 - f1_score: 0.9239 - val_loss: 0.2609 - val_accuracy: 0.9007 - val_f1_score: 0.8991
# Epoch 98/100
# 58/58 [==============================] - 329s 6s/step - loss: 0.1573 - accuracy: 0.9253 - f1_score: 0.9243 - val_loss: 0.2589 - val_accuracy: 0.9011 - val_f1_score: 0.8997
# Epoch 99/100
# 58/58 [==============================] - 331s 6s/step - loss: 0.1558 - accuracy: 0.9256 - f1_score: 0.9246 - val_loss: 0.2569 - val_accuracy: 0.9016 - val_f1_score: 0.9004
# Epoch 100/100
# 58/58 [==============================] - 328s 6s/step - loss: 0.1543 - accuracy: 0.9260 - f1_score: 0.9250 - val_loss: 0.2549 - val_accuracy: 0.9020 - val_f1_score: 0.9010

# %% [markdown]
# ### Plotting accuracy

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.grid()
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.grid()
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# ### Save model to h5

# %%
model.save('Model.h5', save_format='h5')
